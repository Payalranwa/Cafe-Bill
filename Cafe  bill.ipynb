# %%
bill_no=input("Bill no. : ")
date=input("Date : ")
cashier=input(" Enter The Name of The Cashier")
L=["Pizza","Burger","Kadai Panner","Matar paneer","Sahi Paneer","Malai Kofta","Paneer pakode","Hotdog","Gulabjamun","Milk Cake","Ras Malai","Tandoori Roti","Cold Cofee","Kit-Kat Shake","Browni Shake","mojito","sarso ka sag & Makke di Roti","Sev Saamatar & Plane butter Roti","Lassi","Plain Chach"]
M=[350,65,180,140,160,200,150,80,180,220,55,45,120,130,140,100,260,150,85,25]
import pandas as pd
df=pd.DataFrame({"Dish":L,"price":M})
print(df)
empty_list=[]
while True:
    b=int(input("Order the Dish according to it's Position : "))
    
    z=int(input("Enter the quantity of Dish : "))
    c=input("Do you want to order again (Yes\ No) : ")
    price=df["price"][b]*z
    empty_list.append(price)
    total_price=df["price"][b]
    if c=="no":
        print("Thankyou")
        break
total=sum(empty_list)
tex=(total*9.57*2)/100
total_sum=total+tex
print("----------------------------------------------------------------------------------------------------------------------")
print("----------------------------------------------------------------------------------------------------------------------")
print("\n                                             Grand safari Restaurant \n")


print('''  Hotel Safari is located in Jaipur. Museum of Indology and Central Museum are cultural highlights, and travellers
  looking to shop may want to visit World Trade Park and M.I. Road. Looking to enjoy an event or a game while in town?
  See what's happening at Sawai Mansingh Stadium or Birla Auditorium.''',"\n\n")


print("***********************************************************************************************************************")
print("\n                                                      MENU\n")
print("***********************************************************************************************************************")
print("======================================================================================================================")
print("Bill No.                                                                                          Date:")
print(bill_no,"                                                                                         ",date)
print("======================================================================================================================")
print("GST                                                                 =18%")
print("CGST                                                                =9.57%")
print("sGST                                                                =9.57% \n") 
print("                                               Total Amount=",total_sum)
print("======================================================================================================================")
print("Cashier : ",cashier,"\n")
print("======================================================================================================================")
print("                                             Thank You For Your Visit ")
print("                                                 Have A Nice Day")
print("======================================================================================================================")
# Out:
# Bill no. : 123456
# Date : 18/07/2023
#  Enter The Name of The CashierKS
#                                 Dish  price
# 0                              Pizza    350
# 1                             Burger     65
# 2                       Kadai Panner    180
# 3                       Matar paneer    140
# 4                        Sahi Paneer    160
# 5                        Malai Kofta    200
# 6                      Paneer pakode    150
# 7                             Hotdog     80
# 8                         Gulabjamun    180
# 9                          Milk Cake    220
# 10                         Ras Malai     55
# 11                     Tandoori Roti     45
# 12                        Cold Cofee    120
# 13                     Kit-Kat Shake    130
# 14                      Browni Shake    140
# 15                            mojito    100
# 16      sarso ka sag & Makke di Roti    260
# 17  Sev Saamatar & Plane butter Roti    150
# 18                             Lassi     85
# ...
